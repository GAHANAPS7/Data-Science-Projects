# %%
import pandas as pd
import pickle
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('/content/creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# 0  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307
# 1  0.635558  0.463917 -0.114805 -0.183361 -0.145783 -0.069083 -0.225775
# 2  2.345865 -2.890083  1.109969 -0.121359 -2.261857  0.524980  0.247998
# 3 -0.631418 -1.059647 -0.684093  1.965775 -1.232622 -0.208038 -0.108300
# 4  0.175121 -0.451449 -0.237033 -0.038195  0.803487  0.408542 -0.009431
#
#         V22       V23       V24       V25       V26       V27       V28  \
# 0  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
# 1 -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724
# 2  0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752
# 3  0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458
# 4  0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153
#
#    Amount  Class
# 0  149.62    0.0
# 1    2.69    0.0
# 2  378.66    0.0
# 3  123.50    0.0
# 4   69.99    0.0

# %%
df.shape
# Out:
# (7973, 31)

# %%
df.dtypes
# Out:
# Time        int64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class     float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
fraud_count = df["Class"].value_counts()
fraud_rate = 100*fraud_count/df.shape[0]
fraud_data = pd.concat([fraud_count, fraud_rate], axis=1).reset_index()
fraud_data.columns = ['Class', 'Count', 'Percentage']

fraud_data
# Out:
#    Class  Count  Percentage
# 0    0.0   7947   99.673899
# 1    1.0     25    0.313558
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# fraud_data['Class'].plot(kind='hist', bins=20, title='Class')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# fraud_data['Count'].plot(kind='hist', bins=20, title='Count')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# fraud_data['Percentage'].plot(kind='hist', bins=20, title='Percentage')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# fraud_data.plot(kind='scatter', x='Class', y='Count', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# fraud_data.plot(kind='scatter', x='Count', y='Percentage', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Class']
#   ys = series['Count']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = fraud_data.sort_values('Class', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Class')
# _ = plt.ylabel('Count')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Class']
#   ys = series['Percentage']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = fraud_data.sort_values('Class', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Class')
# _ = plt.ylabel('Percentage')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Class']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Class'}, axis=1)
#               .sort_values('Class', ascending=True))
#   xs = counted['Class']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = fraud_data.sort_values('Class', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Class')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# fraud_data['Class'].plot(kind='line', figsize=(8, 4), title='Class')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# fraud_data['Count'].plot(kind='line', figsize=(8, 4), title='Count')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# fraud_data['Percentage'].plot(kind='line', figsize=(8, 4), title='Percentage')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df_fraud = df[df['Class']==1]
df_not_fraud = df[df['Class']==0]
df_not_fraud_sampled = df_not_fraud.sample(df_fraud.shape[0], replace=False, random_state=101)

df_balanced = pd.concat([df_not_fraud_sampled, df_fraud], axis=0).sample(frac=1, replace=False, random_state=101).reset_index().drop('index', axis=1)
df_balanced
# Out:
#      Time        V1        V2        V3        V4        V5        V6  \
# 0    7891 -1.585505  3.261585 -4.137422  2.357096 -1.405043 -1.879437
# 1     376 -0.439946  0.994795  1.357058 -0.050288  0.108030 -0.314621
# 2    1402 -0.018066  0.640409  1.097033  0.235097  0.347753 -0.411686
# 3    7543  0.329594  3.712889 -5.775935  6.078266  1.667359 -2.420168
# 4    4807 -1.716096  0.990185  1.669881 -1.187550  0.154523 -0.204359
# 5    9726 -0.459744  0.879462  2.375614  0.943133  0.153053  1.062495
# 6     472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 7    8808 -4.617217  1.695694 -3.114372  4.328199 -1.873257 -0.989908
# 8    8451  0.314597  2.660670 -5.920037  4.522500 -2.315027 -2.278352
# 9    8878 -2.661802  5.856393 -7.653616  6.379742 -0.060712 -3.131550
# 10   3882 -0.553502  0.700443  1.135328  1.106486  0.701258  0.631258
# 11  10807  1.120416  0.298503  0.622849  1.405907 -0.358557 -0.617385
# 12  10663 -0.565507  0.544953  0.937207 -1.357170  0.965703  0.998878
# 13   8757 -1.863756  3.442644 -4.468260  2.805336 -2.118412 -2.332285
# 14    788 -1.369179  0.594090  1.873669  0.255798  0.255290 -0.245605
# 15   3046  1.141517  0.147296  1.140354  2.471411 -0.257028  1.079995
# 16   8415 -0.251471  4.313523 -6.891438  6.796797  0.616297 -2.966327
# 17   7526  0.008430  4.137837 -6.240697  6.675732  0.768307 -3.353060
# 18   4167  1.125572  0.307932  0.411855  0.684575  0.124763  0.239758
# 19   1824 -4.468051  4.070091 -0.148906 -0.972010 -0.793219 -0.843437
# 20   8528  0.447396  2.481954 -5.660814  4.455923 -2.443780 -2.185040
# 21   8090 -1.783229  3.402794 -3.822742  2.625368 -1.976415 -2.731689
# 22   8614 -2.169929  3.639654 -4.508498  2.730668 -2.122693 -2.341017
# 23   8169  0.857321  4.093912 -7.423894  7.380245  0.973366 -2.730762
# 24   1914  0.748191 -1.041900  1.031218  0.507513 -1.542961 -0.480101
# 25   9064 -3.499108  0.258555 -4.489558  4.853894 -6.974522  3.628382
# 26    406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 27   7551  0.316459  3.809076 -5.615159  6.047445  1.554026 -2.651353
# 28   7740  1.023874  2.001485 -4.769752  3.819195 -1.271754 -1.734662
# 29   1096  0.978872 -0.057622  0.274981  1.247687  0.414369  1.385657
# 30   4462 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 31   7610  0.725646  2.300894 -5.329976  4.007683 -1.730411 -1.732193
# 32   7672  0.702710  2.426433 -5.234513  4.416661 -2.170806 -2.667554
# 33     97  1.273818  0.058009 -1.312428 -0.048969  2.244373  3.296211
# 34   3299  1.044068 -0.223859  1.183273  1.192395 -0.654178  0.966983
# 35   7519  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# 36   3081 -4.360242  5.684778 -3.753719  0.310469  0.239893 -1.863518
# 37  10650 -1.911575 -1.046926  2.339121 -0.221452  1.215863 -1.900629
# 38    331  1.220164  0.330421  0.518020  0.823179 -0.680719 -1.391443
# 39   6986 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 40    994 -0.998151  0.183782  2.121871 -0.350077 -0.057158 -0.941431
# 41   8408 -1.813280  4.917851 -5.926130  5.701500  1.204393 -3.035138
# 42   1877  1.239160 -0.117871  0.267483  0.591171 -0.243513  0.173979
# 43   1860 -0.455258  0.947511  0.874482  0.725765  0.594976 -0.247756
# 44   8886 -2.535852  5.793644 -7.618463  6.395830 -0.065210 -3.136372
# 45   2107 -0.643079  0.901442  1.121471 -2.070913  0.212446 -1.220111
# 46   2919 -0.357294  0.810159  1.130503 -2.046830  0.291410 -1.473388
# 47   4383  1.316401  0.060456 -1.203895 -0.329147  2.216277  3.238492
# 48    273  1.124355 -0.132953  0.588467  0.804871 -0.726266 -0.521875
# 49   7535  0.026779  4.132464 -6.560600  6.348557  1.329666 -2.513479
#
#           V7        V8        V9       V10       V11        V12       V13  \
# 0  -3.513687  1.515607 -1.207166 -6.234561  5.450746  -7.333714  1.361193
# 1   0.500910  0.234651 -0.577012 -0.370060  1.781782   0.422374 -0.658925
# 2   0.552635 -0.240131  0.046819  0.149082 -1.272690  -1.195871 -1.261231
# 3  -0.812891  0.133080 -2.214311 -5.134454  4.560720  -8.873748 -0.797484
# 4   1.657146 -2.817306  5.266792  2.559924  1.286179  -2.068496  2.626155
# 5  -0.000541 -0.171852  1.503606 -0.310825 -0.733386  -2.523928  2.985672
# 6   0.325574 -0.067794 -0.270953 -0.838587 -0.414575  -0.503141  0.676502
# 7  -4.577265  0.472216  0.472017 -5.576023  4.802323 -10.833164  0.104304
# 8  -4.684054  1.202270 -0.694696 -5.526278  6.662437  -8.525465  0.742745
# 9  -3.103570  1.778492 -3.831154 -7.191604  7.102989  -9.928700 -0.067498
# 10  0.798250  0.117787  0.232756 -0.459024  1.673077  -2.332951  1.219295
# 11 -0.043234 -0.134093  1.046098 -0.140506  2.351303  -1.763554  1.222035
# 12  0.326214  0.297776  1.555578 -1.096623  0.336009  -2.118721  1.579662
# 13 -4.261237  1.701682 -1.439396 -6.999907  6.316210  -8.670818  0.316024
# 14  0.664236 -0.400043  0.333039  0.041754 -0.134067   0.765404  0.776814
# 15 -0.690989  0.387962  0.250636  0.467600 -1.579867  -0.327113 -0.403563
# 16 -2.436653  0.489328 -3.371639 -6.810813  7.620089 -10.285283 -0.342444
# 17 -1.631735  0.154612 -2.795892 -6.187891  5.664395  -9.854485 -0.306167
# 18 -0.268136  0.145064  1.060988 -0.571812  3.018936  -1.449495  1.664902
# 19  0.630033  0.151528  2.777562  5.046047  0.723565   0.861761  1.063090
# 20 -4.716143  1.249803 -0.718326 -5.390330  6.454188  -8.485347  0.635281
# 21 -3.430559  1.413204 -0.776941 -6.199882  4.366713  -8.243262  0.345761
# 22 -4.235253  1.703538 -1.305279 -6.716720  6.353612  -8.601648  0.449930
# 23 -1.496497  0.543015 -2.351190 -3.944238  6.355078  -7.309748  0.748451
# 24 -0.312863 -0.050804  1.089734 -0.571641 -0.423995   0.926720  0.397786
# 25  5.431271 -1.946734 -0.775680 -1.987773  4.690396  -6.998042  1.454012
# 26 -2.537387  1.391657 -2.770089 -2.772272  3.202033  -2.899907 -0.595222
# 27 -0.746579  0.055586 -2.678679 -4.959493  6.439053  -7.520117  0.386352
# 28 -3.059245  0.889805  0.415382 -3.955812  3.572055  -7.186452  0.147242
# 29 -0.193881  0.467842  0.347791 -0.267920  0.113950   0.561040 -0.663676
# 30  0.562320 -0.399147 -0.238253 -1.525412  2.032912  -6.560124  0.022937
# 31 -3.968593  1.063728 -0.486097 -4.624985  5.588724  -7.148243  1.680451
# 32 -3.878088  0.911337 -0.166199 -5.009249  4.675729  -8.167188  0.638559
# 33 -0.342625  0.760870 -0.154915  0.068385 -0.161824   0.029225 -0.020632
# 34 -0.934663  0.587055  0.695467  0.050208  1.160928   0.328827 -1.657574
# 35  1.713445 -0.496358 -1.282858 -2.447469  2.101344  -4.609628  1.464378
# 36  1.209372 -0.408977  4.390536  6.541507  2.090066  -0.216967  0.209969
# 37 -0.596554  0.041014  1.593500 -1.355922  0.186610  -2.488491  0.762165
# 38  0.058431 -0.205430  0.082094 -0.266360  0.312676   0.108578 -0.434927
# 39 -3.496197 -0.248778 -0.247768 -4.801637  4.895844 -10.912819  0.184372
# 40 -0.009714  0.070701 -0.091504 -0.504769  0.200231  -0.128346 -0.604343
# 41 -1.713402  0.561257 -3.796354 -7.454841  7.388055 -10.475229 -0.379315
# 42 -0.297429  0.135647  0.521283 -0.022703  0.054031   0.514593 -0.708873
# 43  0.983373 -0.248832 -0.717050 -0.162746 -1.055937   0.227146  1.396089
# 44 -3.104557  1.823233 -3.878658 -7.297803  7.071669 -10.001046 -0.207935
# 45  1.140858 -0.353372  0.892757 -0.907326  0.311768   0.792362  0.394100
# 46  1.265371 -0.519786  0.629535 -1.189299 -0.110345   0.941221  1.130356
# 47 -0.506571  0.663085  1.167570 -0.338401  0.845800  -2.511322  1.644417
# 48 -0.167010  0.059298  0.368093 -0.001930  1.014765   0.596596 -1.346450
# 49 -1.689102  0.303253 -3.139409 -6.045468  6.754625  -8.948179  0.702725
#
#           V14       V15       V16        V17       V18       V19       V20  \
# 0   -6.608068 -0.481069 -2.602478  -4.835112 -0.553026  0.351949  0.315957
# 1   -0.065601  0.500145  0.257425   0.146188 -0.080133 -0.232624  0.046849
# 2    0.221229  1.424221  0.198908  -0.514758  0.145187  0.961228 -0.023306
# 3   -9.177166 -0.257025 -0.871688   1.313014  0.773914 -2.370599  0.269773
# 4   -1.538990  0.249917 -2.112145  -0.108179  0.108153  1.264203 -0.088089
# 5    0.467106  0.289580 -0.364485   0.538858  0.700820  2.145519  0.296407
# 6   -1.692029  2.000635  0.666780   0.599717  1.725321  0.283345  2.102339
# 7   -9.405423 -0.807478 -7.552342  -9.802562 -4.120629  1.740507 -0.039046
# 8   -7.678668  0.593070 -4.478137  -5.844266 -1.102731  2.177386  0.562706
# 9  -10.924187 -1.697914 -2.379421  -2.775114  0.273799 -1.382188  0.399097
# 10   2.160262  0.067013 -0.180818   0.438611  0.291104  0.997140  0.245258
# 11   2.046228 -0.474287  0.277511   0.103189  0.681141 -0.472659 -0.139871
# 12   1.164894 -2.122583  0.212149   0.003223  0.253359  0.105712  0.015058
# 13  -7.417712 -0.436537 -3.652802  -6.293145 -1.243248  0.364810  0.360924
# 14  -0.839730 -0.391300 -1.039528   0.302088 -1.135110 -0.031594 -0.288637
# 15  -0.323053  0.071764  0.599023  -0.408611 -0.306759 -0.880882 -0.205479
# 16 -11.543498 -1.334988 -2.689284  -3.204383  0.086522 -1.314495  0.632710
# 17 -10.691196 -0.638498 -2.041974  -1.129056  0.116453 -1.934666  0.488378
# 18   1.416595  0.171018  0.058802   1.043492 -0.426640 -0.836125 -0.178260
# 19  -1.330984  1.235859 -0.635533  -0.252602 -1.334381 -0.985854  2.322574
# 20  -7.019902  0.539814 -4.649864  -6.288358 -1.339312  2.262985  0.549613
# 21  -6.590550  0.265576 -3.028452  -4.214486 -1.213608 -0.265422  0.364089
# 22  -7.506169 -0.438082 -3.694516  -6.304753 -1.267587  0.357987  0.500779
# 23  -9.057993 -0.648945 -1.073117   1.524501  1.831364 -0.089724  0.483303
# 24  -0.571773 -0.346236 -0.205937   0.244861 -0.752905  0.266939  0.404453
# 25  -3.738023  0.317742 -2.013543  -5.136135 -1.183822  1.663394 -3.042626
# 26  -4.289254  0.389724 -1.140747  -2.830056 -0.016822  0.416956  0.126911
# 27  -9.252307 -1.365188 -0.502362   0.784427  1.494305 -1.808012  0.388307
# 28  -5.249305  1.678334 -2.641473  -1.312059 -0.391716  1.118264  0.204138
# 29   0.258527  0.799637 -1.669704   1.215433 -2.408052 -1.561997 -0.281286
# 30  -1.470102 -0.698826 -2.282194  -4.781831 -2.615665 -1.334441 -0.430022
# 31  -6.210258  0.495282 -3.599540  -4.830324 -0.649090  2.250123  0.504646
# 32  -6.763334  1.296860 -3.811758  -3.754128 -1.049177  1.554197  0.422743
# 33   0.528189  1.105977  0.375592  -0.926725  0.292544 -0.002887  0.008906
# 34   0.314488  0.565935 -0.034772  -0.016393 -0.010935 -0.907463 -0.300466
# 35  -6.079337 -0.339237  2.581851   6.739384  3.042493 -2.721853  0.009061
# 36  -5.839629  1.690685 -0.352422   2.681226  0.444050 -1.555830  3.234500
# 37   1.283713 -1.509138 -0.348873   0.895326 -0.321996 -0.341821  0.277349
# 38  -0.142860  1.117224  0.349960   0.220439 -0.403224 -0.394698 -0.136175
# 39  -6.771097 -0.007326 -7.358083 -12.598419 -5.131549  0.308334 -0.171608
# 40   0.147141  1.370459 -0.022745   0.111766 -0.802208 -0.371699 -0.108662
# 41 -11.736729 -2.086989 -2.442354  -3.535524  0.130360 -2.071450  0.576656
# 42   0.096130 -0.963781  0.104118  -0.420737  0.286837  0.792547 -0.130528
# 43   0.012280  0.964739 -0.128311  -0.578782  0.238166  0.753605  0.065121
# 44 -10.860698 -1.690825 -2.360857  -2.760097  0.298103 -1.385558  0.408704
# 45  -0.079399  1.050391 -1.022497  -0.221326 -0.613399 -0.618026  0.162443
# 46  -0.188297  0.735688 -0.644543  -0.646950 -0.123299 -0.110829  0.116380
# 47   1.911147  0.387655  0.429846  -0.121798  0.389670 -0.033403 -0.011336
# 48   0.382687 -0.791900 -0.086204  -0.075735 -0.133082  0.431188 -0.139533
# 49 -10.733854 -1.379520 -1.638960  -1.746350  0.776744 -1.327357  0.587743
#
#          V21       V22       V23       V24       V25       V26       V27  \
# 0   0.501543 -0.546869 -0.076584 -0.425550  0.123644  0.321985  0.264028
# 1  -0.178158 -0.476767  0.036740  0.155321 -0.311973  0.073609  0.254203
# 2  -0.262232 -0.696158 -0.044294 -0.504117 -0.647640  0.108583 -0.232884
# 3   0.156617 -0.652450 -0.551572 -0.716522  1.415717  0.555265  0.530507
# 4   0.017830  1.357057 -0.056061  0.417201 -1.259833 -1.159825 -3.882496
# 5  -0.282243 -0.198606 -0.423094 -0.983384  0.103947  0.592509 -0.347143
# 6   0.661696  0.435477  1.375966 -0.293803  0.279798 -0.145362 -0.252773
# 7   0.481830  0.146023  0.117039 -0.217565 -0.138776 -0.424453 -1.002041
# 8   0.743314  0.064038  0.677842  0.083008 -1.911034  0.322188  0.620867
# 9   0.734775 -0.435901 -0.384766 -0.286016  1.007934  0.413196  0.280284
# 10 -0.412264 -1.236580  0.331004 -0.974366 -0.549998 -0.741931  0.097090
# 11 -0.000568  0.172352 -0.107328  0.483208  0.570640 -0.351836 -0.020087
# 12 -0.227760 -0.135346 -0.332376 -1.691002 -0.055543  0.980261  0.259983
# 13  0.667927 -0.516242 -0.012218  0.070614  0.058504  0.304883  0.418012
# 14  0.008820  0.534893 -0.067220  0.492594 -0.057231  0.320766 -0.664510
# 15 -0.120525 -0.179897 -0.021903 -0.793308  0.317297  0.040616  0.054698
# 16  0.536892 -0.546126 -0.605240 -0.263743  1.539916  0.523574  0.891025
# 17  0.364514 -0.608057 -0.539528  0.128940  1.488481  0.507963  0.735822
# 18 -0.330118 -0.679265  0.188298 -0.390101  0.012130  0.097738 -0.021273
# 19 -0.745320 -0.662027  0.210637  0.342283  0.581766  0.098361  1.575545
# 20  0.756053  0.140168  0.665411  0.131464 -1.908217  0.334808  0.748534
# 21  0.454032 -0.577526  0.045967  0.461700  0.044146  0.305704  0.530981
# 22  0.645103 -0.503529 -0.000523  0.071696  0.092007  0.308498  0.552591
# 23  0.375026  0.145400  0.240603 -0.234649 -1.004881  0.435832  0.618324
# 24 -0.069211 -0.437001 -0.085490  0.822241  0.023996  0.896132 -0.073521
# 25 -1.052368  0.204817 -2.119007  0.170279 -0.393844  0.296367  1.985913
# 26  0.517232 -0.035049 -0.465211  0.320198  0.044519  0.177840  0.261145
# 27  0.208828 -0.511747 -0.583813 -0.219845  1.474753  0.491192  0.518868
# 28  0.343283 -0.054196  0.709654 -0.372216 -2.032068  0.366778  0.395171
# 29 -0.002420  0.272978  0.021821 -0.959211  0.397657 -0.214306  0.087509
# 30 -0.294166 -0.932391  0.172726 -0.087330 -0.156114 -0.542628  0.039566
# 31  0.589669  0.109541  0.601045 -0.364700 -1.843078  0.351909  0.594550
# 32  0.551180 -0.009802  0.721698  0.473246 -1.959304  0.319476  0.600485
# 33 -0.017292 -0.182883 -0.146981  1.004700  0.842883 -0.314281  0.013744
# 34  0.209899  0.745237 -0.016587 -0.302822  0.275162 -0.194983  0.087403
# 35 -0.379068 -0.704181 -0.656805 -1.632653  1.488901  0.566797 -0.010016
# 36 -1.005170 -0.255062  0.285958 -0.028311  0.434955 -0.515676  0.886544
# 37 -0.060918 -0.324612  0.025386  0.728057  0.439552  0.970636 -0.143701
# 38 -0.259713 -0.778005  0.202685  0.862149  0.126259  0.063438 -0.025917
# 39  0.573574  0.176968 -0.436207 -0.053502  0.252405 -0.657488 -0.827136
# 40 -0.035188 -0.201976  0.071740  0.628963 -0.698220  0.730304 -0.058889
# 41  0.615642 -0.406427 -0.737018 -0.279642  1.106766  0.323885  0.894767
# 42 -0.098996 -0.102705 -0.195331 -0.454811  0.642068  0.474574 -0.025379
# 43  0.119261  0.469382 -0.104337 -0.419679 -0.072759 -0.292285  0.081254
# 44  0.716720 -0.448060 -0.402407 -0.288835  1.011752  0.425965  0.413140
# 45  0.088436  0.763715 -0.222559  0.420561  0.031411 -0.827807  0.365131
# 46  0.076002  0.665246 -0.312068  0.428111  0.118601 -0.844017  0.247677
# 47 -0.200407 -0.461827 -0.094596  0.981876  0.661866  0.373313 -0.067411
# 48 -0.165166 -0.446871  0.017617  0.548845  0.347079  0.239948 -0.038564
# 49  0.370509 -0.576752 -0.669605 -0.759908  1.605056  0.540675  0.737040
#
#          V28   Amount  Class
# 0   0.132817     1.00    1.0
# 1   0.085367     4.45    0.0
# 2  -0.169556     1.98    0.0
# 3   0.404474     1.00    1.0
# 4  -1.738014    44.93    0.0
# 5  -0.156162     6.99    0.0
# 6   0.035764   529.00    1.0
# 7   0.890780     1.10    1.0
# 8   0.185030     1.00    1.0
# 9   0.303937     1.00    1.0
# 10  0.138216   110.95    0.0
# 11  0.012188    34.90    0.0
# 12  0.145320    16.10    0.0
# 13  0.208858     1.00    1.0
# 14 -0.072142     9.95    0.0
# 15  0.022472     0.00    0.0
# 16  0.572741     1.00    1.0
# 17  0.513574     1.00    1.0
# 18  0.007590     3.58    0.0
# 19  0.768739     9.85    0.0
# 20  0.175414     1.00    1.0
# 21  0.243746     1.00    1.0
# 22  0.298954     1.00    1.0
# 23  0.148469     1.00    1.0
# 24  0.058383   236.60    0.0
# 25 -0.900452  1809.68    1.0
# 26 -0.143276     0.00    1.0
# 27  0.402528     1.00    1.0
# 28  0.020206     1.00    1.0
# 29  0.007426    30.33    0.0
# 30 -0.153029   239.93    1.0
# 31  0.099372     1.00    1.0
# 32  0.129305     1.00    1.0
# 33  0.015907    17.80    0.0
# 34  0.014752     1.00    0.0
# 35  0.146793     1.00    1.0
# 36 -0.629143     0.89    0.0
# 37  0.070313    13.00    0.0
# 38  0.034840     0.89    0.0
# 39  0.849573    59.00    1.0
# 40  0.137676    11.43    0.0
# 41  0.569519     1.00    1.0
# 42 -0.009183     6.99    0.0
# 43  0.137054    46.73    0.0
# 44  0.308205     1.00    1.0
# 45  0.047755     1.00    0.0
# 46 -0.010778     1.00    0.0
# 47 -0.002459    11.72    0.0
# 48  0.006765    32.51    0.0
# 49  0.496699     1.00    1.0

# %%
fraud_count = df_balanced["Class"].value_counts()
fraud_rate = 100*fraud_count/df_balanced.shape[0]
fraud_data = pd.concat([fraud_count, fraud_rate], axis=1).reset_index()
fraud_data.columns = ['Class', 'Count', 'Percentage']

fraud_data
# Out:
#    Class  Count  Percentage
# 0    1.0     25        50.0
# 1    0.0     25        50.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# fraud_data['Class'].plot(kind='hist', bins=20, title='Class')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Count']
#   ys = series['Class']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = fraud_data.sort_values('Count', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Count')
# _ = plt.ylabel('Class')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Count']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Count'}, axis=1)
#               .sort_values('Count', ascending=True))
#   xs = counted['Count']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = fraud_data.sort_values('Count', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Count')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Percentage']
#   ys = series['Class']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = fraud_data.sort_values('Percentage', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Percentage')
# _ = plt.ylabel('Class')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Percentage']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Percentage'}, axis=1)
#               .sort_values('Percentage', ascending=True))
#   xs = counted['Percentage']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = fraud_data.sort_values('Percentage', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Percentage')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# fraud_data['Class'].plot(kind='line', figsize=(8, 4), title='Class')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
X_train, X_test, y_train, y_test = train_test_split(df_balanced.drop('Class', axis=1), df_balanced['Class'], test_size=0.2, random_state=101)

print(f'''X_train: {X_train.shape}
X_test: {X_test.shape}
y_train: {y_train.shape}
y_test: {y_test.shape}''')
# Out:
# X_train: (40, 30)
# X_test: (10, 30)
# y_train: (40,)
# y_test: (10,)

# %%
randomForestModel = Pipeline([
    ('scaler', StandardScaler()),
    ('classifier', RandomForestClassifier())
])

randomForestModel.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('classifier', RandomForestClassifier())])

# %%
y_pred_logis = randomForestModel.predict(X_test)
y_pred_logis
# Out:
# array([0., 0., 1., 1., 1., 0., 1., 0., 0., 0.])

# %%
cr = classification_report(y_test, y_pred_logis)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         6
#          1.0       1.00      1.00      1.00         4
#
#     accuracy                           1.00        10
#    macro avg       1.00      1.00      1.00        10
# weighted avg       1.00      1.00      1.00        10
